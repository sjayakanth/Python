# %%
import pandas as pd

# %% [markdown]
# ### Types
#     1. Series - 1 dimension
#     2. Dataframe - 2 dimension -axis 1 : columns, 0 : rows/index

# %%
#https://www.kaggle.com/datasets/vivamoto/us-adult-income-update
census_data = pd.read_csv('.././csv/census-income.csv')

# %%
df = pd.DataFrame(data=census_data)

# %%
df.head(5)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country annual_income
# 0          2174             0              40  United-States         <=50K
# ...

# %%
df.sample(5)
# Out:
#        age  workclass  fnlwgt     education  education-num  \
# 5209    25          ?  262245     Assoc-voc             11
# 10178   43    Private  173316  Some-college             10
# 19384   44  Local-gov  124924     Assoc-voc             11
# 4831    56    Private  398067       HS-grad              9
# 14510   38    Private  380543       HS-grad              9
#
#            marital-status     occupation   relationship   race     sex  \
# 5209        Never-married              ?      Own-child  White  Female
# 10178  Married-civ-spouse   Craft-repair        Husband  White    Male
# 19384       Never-married   Craft-repair  Not-in-family  White    Male
# 4831              Widowed   Adm-clerical  Not-in-family  White  Female
# 14510       Never-married  Other-service      Unmarried  Black  Female
#
#        capital-gain  capital-loss  hours-per-week native-country annual_income
# 5209           3418             0              40  United-States         <=50K
# ...

# %%
df.tail(5)
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country annual_income
# 32556             0             0              38  United-States         <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  annual_income   32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# ### accessing
#     1.  loc - actual column and index
#     2.  iloc - location of column and index

# %%
df.loc[0:5,'age':'education'] # start : stop-1 : step
# Out:
#    age         workclass  fnlwgt  education
# 0   39         State-gov   77516  Bachelors
# 1   50  Self-emp-not-inc   83311  Bachelors
# 2   38           Private  215646    HS-grad
# 3   53           Private  234721       11th
# 4   28           Private  338409  Bachelors
# 5   37           Private  284582    Masters

# %%
df.iloc[0:5,0:4]
# Out:
#    age         workclass  fnlwgt  education
# 0   39         State-gov   77516  Bachelors
# 1   50  Self-emp-not-inc   83311  Bachelors
# 2   38           Private  215646    HS-grad
# 3   53           Private  234721       11th
# 4   28           Private  338409  Bachelors

# %%
df['age'].iloc[0]
# Out:
# 39

# %%
colummns =  ['age','workclass']
df[colummns].iloc[10:16]
# Out:
#     age  workclass
# 10   37    Private
# 11   30  State-gov
# 12   23    Private
# 13   32    Private
# 14   40    Private
# 15   34    Private

# %%
condition = df['workclass'] == 'Private' 
df[condition]
# Out:
#        age workclass  fnlwgt     education  education-num  \
# 2       38   Private  215646       HS-grad              9
# 3       53   Private  234721          11th              7
# 4       28   Private  338409     Bachelors             13
# 5       37   Private  284582       Masters             14
# 6       49   Private  160187           9th              5
# ...    ...       ...     ...           ...            ...
# 32555   22   Private  310152  Some-college             10
# 32556   27   Private  257302    Assoc-acdm             12
# 32557   40   Private  154374       HS-grad              9
# 32558   58   Private  151910       HS-grad              9
# 32559   22   Private  201490       HS-grad              9
#
#               marital-status         occupation   relationship   race     sex  \
# 2                   Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3         Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# ...

# %%
df.iloc[0:]
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#        'marital-status', 'occupation', 'relationship', 'race', 'sex',
#        'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#        'annual_income'],
#       dtype='object')

# %%
df.shape # row, columns
# Out:
# (32561, 15)

# %%
df.ndim #dimensions x,y row,col
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=32561, step=1),
#  Index(['age', 'workclass', 'fnlwgt', 'education', 'education-num',
#         'marital-status', 'occupation', 'relationship', 'race', 'sex',
#         'capital-gain', 'capital-loss', 'hours-per-week', 'native-country',
#         'annual_income'],
#        dtype='object')]

# %%
df.describe().T #statistical information 
# T - Transpose : converts you rows to column
# Out:
#                   count           mean            std      min       25%  \
# age             32561.0      38.581647      13.640433     17.0      28.0
# fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# education-num   32561.0      10.080679       2.572720      1.0       9.0
# capital-gain    32561.0    1077.648844    7385.292085      0.0       0.0
# capital-loss    32561.0      87.303830     402.960219      0.0       0.0
# hours-per-week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# age                 37.0      48.0       90.0
# fnlwgt          178356.0  237051.0  1484705.0
# education-num       10.0      12.0       16.0
# capital-gain         0.0       0.0    99999.0
# capital-loss         0.0       0.0     4356.0
# hours-per-week      40.0      45.0       99.0

# %%
condition = df['workclass'] == 'Private'
df[condition].sort_values(by='age',ascending=False)
# Out:
#        age workclass  fnlwgt     education  education-num      marital-status  \
# 11512   90   Private   87285       HS-grad              9       Never-married
# 1040    90   Private  137018       HS-grad              9       Never-married
# 2891    90   Private  171956  Some-college             10           Separated
# 10545   90   Private  175491       HS-grad              9  Married-civ-spouse
# 6624    90   Private  313986          11th              7  Married-civ-spouse
# ...    ...       ...     ...           ...            ...                 ...
# 14157   17   Private  270942       HS-grad              9       Never-married
# 1389    17   Private   46496          11th              7       Never-married
# 30328   17   Private  128617          10th              6       Never-married
# 30889   17   Private  169155          12th              8       Never-married
# 25775   17   Private  239947          11th              7       Never-married
#
# ...

# %%
df['marital-status'].value_counts() # category + counts
df['marital-status'].nunique() # no.of catergories n :Numeric
df['marital-status'].unique() # List catergories
# Out:
# array(['Never-married', 'Married-civ-spouse', 'Divorced',
#        'Married-spouse-absent', 'Separated', 'Married-AF-spouse',
#        'Widowed'], dtype=object)

# %% [markdown]
# # Task
#
#     1. Select columns from 4 to 10
#     2. Sort values based on their hours-per-week
#     3. Counts based Gender
#     4. condition age > 50 & gender male
